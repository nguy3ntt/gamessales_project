# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

games = pd.read_excel('C:/Users/ADMIN/Downloads/gamessales_project/dataset/VideoGames_Sales.xlsx')
games.head(10)
# Out:
#                             title console             genre       publisher  \
# 0              Grand Theft Auto V     PS3            Action  Rockstar Games
# 1              Grand Theft Auto V     PS4            Action  Rockstar Games
# 2     Grand Theft Auto: Vice City     PS2            Action  Rockstar Games
# 3              Grand Theft Auto V    X360            Action  Rockstar Games
# 4       Call of Duty: Black Ops 3     PS4           Shooter      Activision
# 5  Call of Duty: Modern Warfare 3    X360           Shooter      Activision
# 6         Call of Duty: Black Ops    X360           Shooter      Activision
# 7           Red Dead Redemption 2     PS4  Action-Adventure  Rockstar Games
# 8      Call of Duty: Black Ops II    X360           Shooter      Activision
# 9      Call of Duty: Black Ops II     PS3           Shooter      Activision
#
#         developer  critic_score  total_sales(mil)  na_sales(mil)  \
# 0  Rockstar North           9.4             20.32           6.37
# 1  Rockstar North           9.7             19.39           6.06
# 2  Rockstar North           9.6             16.15           8.41
# 3  Rockstar North           NaN             15.86           9.06
# 4        Treyarch           8.1             15.09           6.18
# 5   Infinity Ward           8.7             14.82           9.07
# 6        Treyarch           8.8             14.74           9.76
# 7  Rockstar Games           9.8             13.94           5.26
# 8        Treyarch           8.4             13.86           8.27
# 9        Treyarch           8.0             13.80           4.99
#
#    jp_sales(mil)  pal_sales(mil)  other_sales(mil) release_date
# 0           0.99            9.85              3.12   2013-09-17
# 1           0.60            9.71              3.02   2014-11-18
# 2           0.47            5.49              1.78   2002-10-28
# 3           0.06            5.33              1.42   2013-09-17
# 4           0.41            6.05              2.44   2015-11-06
# 5           0.13            4.29              1.33   2011-11-08
# 6           0.11            3.73              1.14   2010-11-09
# 7           0.21            6.21              2.26   2018-10-26
# 8           0.07            4.32              1.20   2012-11-13
# 9           0.65            5.88              2.28   2012-11-13

# %%
print(f'games shape: {games.shape}')
print(f'games columns: {games.columns}')
# Out:
# games shape: (64016, 12)
# games columns: Index(['title', 'console', 'genre', 'publisher', 'developer', 'critic_score',
#        'total_sales(mil)', 'na_sales(mil)', 'jp_sales(mil)', 'pal_sales(mil)',
#        'other_sales(mil)', 'release_date'],
#       dtype='object')

# %%
print(games.isnull().sum())
# Out:
# title                   0
# console                 0
# genre                   0
# publisher               0
# developer              17
# critic_score        57338
# total_sales(mil)    45094
# na_sales(mil)       51379
# jp_sales(mil)       57290
# pal_sales(mil)      51192
# other_sales(mil)    48888
# release_date         7051
# dtype: int64
